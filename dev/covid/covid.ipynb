# %% [markdown]
# # Introduction
# In this short notebook, we transform the data about covid (add some information) in order to send it to Google Data Studio.

# %%
import numpy as np
import pandas as pd

# %%
# the data has been downloaded from here: https://data.europa.eu/euodp/en/data/dataset/covid-19-coronavirus-data
df_covid = pd.read_csv("data/covid.csv")
df_covid.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  22/09/2020   22      9  2020     30       3             Afghanistan    AF
# 1  21/09/2020   21      9  2020      0       0             Afghanistan    AF
# 2  20/09/2020   20      9  2020    125       4             Afghanistan    AF
# 3  19/09/2020   19      9  2020     47       1             Afghanistan    AF
# 4  18/09/2020   18      9  2020      0       0             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.524640
# 1                                           1.698134
# 2                                           1.892657
# 3                                           1.616645
# 4                                           1.535155

# %% [markdown]
# # Data transformation and enrichment

# %%
# select and rename some features for better readability
df_covid = df_covid.rename(index=str, columns={
    "dateRep": "date", 
    "popData2019": "population",
    "countriesAndTerritories": "country_name",
    "geoId": "country_id",
})[[
    "date",
    "population",
    "country_name",
    "country_id",
    "cases",
    "deaths",
    "day",
    "month",
    "year",
]]

df_covid.head()
# Out:
#          date  population country_name country_id  cases  deaths  day  month  \
# 0  22/09/2020  38041757.0  Afghanistan         AF     30       3   22      9
# 1  21/09/2020  38041757.0  Afghanistan         AF      0       0   21      9
# 2  20/09/2020  38041757.0  Afghanistan         AF    125       4   20      9
# 3  19/09/2020  38041757.0  Afghanistan         AF     47       1   19      9
# 4  18/09/2020  38041757.0  Afghanistan         AF      0       0   18      9
#
#    year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020

# %%
# casting of date
df_covid["date_measure"] = pd.to_datetime(
    df_covid["year"]*10000+df_covid["month"]*100+df_covid["day"],format='%Y%m%d'
)
df_covid.head()
# Out:
#          date  population country_name country_id  cases  deaths  day  month  \
# 0  22/09/2020  38041757.0  Afghanistan         AF     30       3   22      9
# 1  21/09/2020  38041757.0  Afghanistan         AF      0       0   21      9
# 2  20/09/2020  38041757.0  Afghanistan         AF    125       4   20      9
# 3  19/09/2020  38041757.0  Afghanistan         AF     47       1   19      9
# 4  18/09/2020  38041757.0  Afghanistan         AF      0       0   18      9
#
#    year date_measure
# 0  2020   2020-09-22
# 1  2020   2020-09-21
# 2  2020   2020-09-20
# 3  2020   2020-09-19
# 4  2020   2020-09-18

# %%
# compute the cumulative cases and deaths
df_covid_cum = df_covid.groupby(
    ['country_name','date_measure']
).sum().groupby('country_name').cumsum()[["cases","deaths"]]
df_covid_cum = df_covid_cum.reset_index()
df_covid_cum = df_covid_cum.rename(index=str, columns={
    "cases": "cases_cumulative", 
    "deaths": "deaths_cumulative",
})
df_covid_cum.head()
# Out:
#   country_name date_measure  cases_cumulative  deaths_cumulative
# 0  Afghanistan   2019-12-31                 0                  0
# 1  Afghanistan   2020-01-01                 0                  0
# 2  Afghanistan   2020-01-02                 0                  0
# 3  Afghanistan   2020-01-03                 0                  0
# 4  Afghanistan   2020-01-04                 0                  0

# %%
# simple sort
df_covid = pd.merge(df_covid, df_covid_cum, how='inner', on=["date_measure","country_name"])
df_covid = df_covid.sort_values(['date_measure', 'country_name'], ascending=[1, 1])
df_covid.head()
# Out:
#             date  population country_name country_id  cases  deaths  day  \
# 256   31/12/2019  38041757.0  Afghanistan         AF      0       0   31
# 716   31/12/2019  43053054.0      Algeria         DZ      0       0   31
# 1919  31/12/2019   2957728.0      Armenia         AM      0       0   31
# 2370  31/12/2019  25203200.0    Australia         AU      0       0   31
# 2637  31/12/2019   8858775.0      Austria         AT      0       0   31
#
#       month  year date_measure  cases_cumulative  deaths_cumulative
# 256      12  2019   2019-12-31                 0                  0
# 716      12  2019   2019-12-31                 0                  0
# 1919     12  2019   2019-12-31                 0                  0
# 2370     12  2019   2019-12-31                 0                  0
# 2637     12  2019   2019-12-31                 0                  0

# %%
# compute the proportion of cases and deaths to the each population size.
df_covid["cases_in_1M"] = df_covid.apply(
    lambda row: (1000000 * row["cases_cumulative"]) / row["population"], axis=1)
df_covid["deaths_in_1M"] = df_covid.apply(
    lambda row: (1000000 * row["deaths_cumulative"]) / row["population"], axis=1)
df_covid[df_covid["country_name"]=="France"].tail()
# Out:
#              date  population country_name country_id  cases  deaths  day  \
# 14641  18/09/2020  67012883.0       France         FR  10593      50   18
# 14640  19/09/2020  67012883.0       France         FR  13215     154   19
# 14639  20/09/2020  67012883.0       France         FR  13498      25   20
# 14638  21/09/2020  67012883.0       France         FR  11569      11   21
# 14637  22/09/2020  67012883.0       France         FR   4298      53   22
#
#        month  year date_measure  cases_cumulative  deaths_cumulative  \
# 14641      9  2020   2020-09-18            415481              31095
# 14640      9  2020   2020-09-19            428696              31249
# 14639      9  2020   2020-09-20            442194              31274
# 14638      9  2020   2020-09-21            453763              31285
# 14637      9  2020   2020-09-22            458061              31338
#
#        cases_in_1M  deaths_in_1M
# 14641  6200.016794    464.015255
# 14640  6397.217681    466.313321
# 14639  6598.641637    466.686383
# 14638  6771.280084    466.850531
# 14637  6835.417005    467.641424

# %%
# rename the columns so that they are Data Studio friendly.
df_covid = df_covid[[
    "date_measure", 
    "country_name", 
    "country_id", 
    "cases",
    "deaths",
    "population",
    "cases_cumulative",
    "deaths_cumulative",
    "cases_in_1M",
    "deaths_in_1M",
]]

df_covid = df_covid.rename(index=str, columns={
    "date_measure": "Date of measure", 
    "country_name": "Country name", 
    "country_id": "Country id", 
    "cases": "Cases",
    "deaths": "Deaths",
    "population": "Population size",
    "cases_cumulative": "Cumulative cases",
    "deaths_cumulative": "Cumulative deaths",
    "cases_in_1M": "Cases to population",
    "deaths_in_1M": "Deaths to population",
})
df_covid.head()
# Out:
#      Date of measure Country name Country id  Cases  Deaths  Population size  \
# 256       2019-12-31  Afghanistan         AF      0       0       38041757.0
# 716       2019-12-31      Algeria         DZ      0       0       43053054.0
# 1919      2019-12-31      Armenia         AM      0       0        2957728.0
# 2370      2019-12-31    Australia         AU      0       0       25203200.0
# 2637      2019-12-31      Austria         AT      0       0        8858775.0
#
#       Cumulative cases  Cumulative deaths  Cases to population  \
# 256                  0                  0                  0.0
# 716                  0                  0                  0.0
# 1919                 0                  0                  0.0
# 2370                 0                  0                  0.0
# 2637                 0                  0                  0.0
#
#       Deaths to population
# 256                    0.0
# 716                    0.0
# 1919                   0.0
# 2370                   0.0
# 2637                   0.0

# %%
df_covid.to_csv("data/output/covid_parsed_05.csv", index=False)

# %% [markdown]
# # Additional analysis

# %%
# are there rows where the cases are negative?
df_covid[df_covid["Cases"]<0]
# Out:
#       Date of measure                                Country name Country id  \
# 7864       2020-03-10  Cases_on_an_international_conveyance_Japan   JPG11668
# 37989      2020-04-19                                       Spain         ES
# 24594      2020-04-29                                   Lithuania         LT
# 32981      2020-05-03                                    Portugal         PT
# 12215      2020-05-07                                     Ecuador         EC
# 12213      2020-05-09                                     Ecuador         EC
# 34899      2020-05-11                                  San_Marino         SM
# 12210      2020-05-12                                     Ecuador         EC
# 4568       2020-05-20                                       Benin         BJ
# 41397      2020-05-21                                      Uganda         UG
# 37953      2020-05-25                                       Spain         ES
# 41385      2020-06-02                                      Uganda         UG
# 14748      2020-06-03                                      France         FR
# 21059      2020-06-20                                       Italy         IT
# 21942      2020-07-22                                      Jordan         JO
# 24731      2020-08-28                                  Luxembourg         LU
# 12092      2020-09-07                                     Ecuador         EC
# 21704      2020-09-11                                      Jersey         JE
#
#        Cases  Deaths  Population size  Cumulative cases  Cumulative deaths  \
# 7864      -9       1              NaN               696                  7
# 37989   -713     410       46937060.0            193252              20453
# 24594   -105       3        2794184.0              1344                 44
# 32981   -161      16       10276617.0             25190               1023
# 12215  -2461      49       17373657.0             29420               1618
# 12213  -1480      50       17373657.0             28818               1704
# 34899     -9       0          34453.0               628                 41
# 12210    -50      18       17373657.0             29509               2145
# 4568    -209       0       11801151.0               130                  2
# 41397   -115       0       44269587.0               145                  0
# 37953   -372   -1918       46937060.0            235400              26834
# 41385     -1       0       44269587.0               457                  0
# 14748   -766     107       67012883.0            151325              28940
# 21059   -148      47       60359546.0            238011              34561
# 21942   -110       0       10101697.0              1113                 11
# 24731  -1385       0         613894.0              6543                124
# 12092  -8261    3800       17373657.0            109784              10524
# 21704     -6       0         107796.0               379                 32
#
#        Cases to population  Deaths to population
# 7864                   NaN                   NaN
# 37989          4117.258303            435.753752
# 24594           480.999104             15.746994
# 32981          2451.195758             99.546378
# 12215          1693.368299             93.129501
# 12213          1658.718139             98.079523
# 34899         18227.730531           1190.026993
# 12210          1698.490997            123.462780
# 4568             11.015875              0.169475
# 41397             3.275386              0.000000
# 37953          5015.226774            571.701764
# 41385            10.323114              0.000000
# 14748          2258.147885            431.857259
# 21059          3943.220514            572.585486
# 21942           110.179507              1.088926
# 24731         10658.191805            201.989269
# 12092          6318.992023            605.744663
# 21704          3515.900404            296.857026

# %%
# sort by last death proportion to the population size (descending)
df_covid_temp_gp = df_covid.groupby(['Country name']).max()[["Deaths to population"]]
df_covid_temp_gp = df_covid_temp_gp.reset_index()
df_covid_temp_gp = df_covid_temp_gp.sort_values(['Deaths to population'], ascending=[0])
df_covid_temp_gp.head(10)
# Out:
#        Country name  Deaths to population
# 164      San_Marino           1219.052042
# 152            Peru            968.119124
# 18          Belgium            868.576972
# 3           Andorra            695.748060
# 23          Bolivia            664.807799
# 179           Spain            653.279093
# 27           Brazil            650.425552
# 41            Chile            648.901292
# 58          Ecuador            638.610512
# 198  United_Kingdom            627.003913

# %%
df_country_pop = df_covid[["Country name","Country id","Population size"]].drop_duplicates()
df_country_pop.to_csv("data/output/country_population.csv", index=False)

# %%
zipped = zip(df_country_pop["Country id"], df_country_pop["Population size"]) 
print(zipped)
country_pop_dict = dict(zipped)
print(country_pop_dict)
# Out:
# <zip object at 0x7ffd21f7d808>
# {'AF': 38041757.0, 'DZ': 43053054.0, 'AM': 2957728.0, 'AU': 25203200.0, 'AT': 8858775.0, 'AZ': 10047719.0, 'BH': 1641164.0, 'BY': 9452409.0, 'BE': 11455519.0, 'BR': 211049519.0, 'KH': 16486542.0, 'CA': 37411038.0, 'JPG11668': nan, 'CN': 1433783692.0, 'HR': 4076246.0, 'CZ': 10649800.0, 'DK': 5806081.0, 'DO': 10738957.0, 'EC': 17373657.0, 'EG': 100388076.0, 'EE': 1324820.0, 'FI': 5517919.0, 'FR': 67012883.0, 'GE': 3996762.0, 'DE': 83019213.0, 'EL': 10724599.0, 'IS': 356991.0, 'IN': 1366417756.0, 'ID': 270625567.0, 'IR': 82913893.0, 'IQ': 39309789.0, 'IE': 4904240.0, 'IL': 8519373.0, 'IT': 60359546.0, 'JP': 126860299.0, 'KW': 4207077.0, 'LB': 6855709.0, 'LT': 2794184.0, 'LU': 613894.0, 'MY': 31949789.0, 'MX': 127575529.0, 'MC': 33085.0, 'NP': 28608715.0, 'NL': 17282163.0, 'NZ': 4783062.0, 'NG': 200963603.0, 'MK': 2077132.0, 'NO': 5328212.0, 'OM': 4974992.0, 'PK': 216565317.0, 'PH': 108116622.0, 'QA': 2832071.0, 'RO': 19414458.0, 'RU': 145872260.0, 'SM': 34453.0, 'SG': 5804343.0, 'KR': 51225321.0, 'ES': 46937060.0, 'LK': 21323734.0, 'SE': 10230185.0, 'CH': 8544527.0, 'TW': 23773881.0, 'TH': 69625581.0, 'AE': 9770526.0, 'UK': 66647112.0, 'US': 329064917.0, 'VN': 96462108.0, 'AD': 76177.0, 'JO': 10101697.0, 'LV': 1919968.0, 'MA': 36471766.0, 'PT': 10276617.0, 'SA': 34268529.0, 'SN': 16296362.0, 'SX': 42389.0, 'TN': 11694721.0, 'AR': 44780675.0, 'CL': 18952035.0, 'PL': 37972812.0, 'UA': 43993643.0, 'HU': 9772756.0, 'LI': 38378.0, 'SI': 2080908.0, 'BT': 763094.0, 'BA': 3300998.0, 'FO': 48677.0, 'PS': 4981422.0, 'ZA': 58558267.0, 'CM': 25876387.0, 'CO': 50339443.0, 'CR': 5047561.0, 'VA': 815.0, 'MT': 493559.0, 'PE': 32510462.0, 'RS': 6963764.0, 'SK': 5450421.0, 'TG': 8082359.0, 'BG': 7000039.0, 'MV': 530957.0, 'MD': 4043258.0, 'PY': 7044639.0, 'AL': 2862427.0, 'BD': 163046173.0, 'BN': 433296.0, 'CY': 875899.0, 'MN': 3225166.0, 'PA': 4246440.0, 'BF': 20321383.0, 'CD': 86790568.0, 'BO': 11513102.0, 'CI': 25716554.0, 'CU': 11333484.0, 'HN': 9746115.0, 'JM': 2948277.0, 'TR': 82003882.0, 'AW': 106310.0, 'CW': 163423.0, 'GA': 2172578.0, 'GH': 30417858.0, 'GY': 782775.0, 'VC': 110593.0, 'TT': 1394969.0, 'ET': 112078727.0, 'GN': 12771246.0, 'KE': 52573967.0, 'XK': 1798506.0, 'SD': 42813237.0, 'AG': 97115.0, 'GQ': 1355982.0, 'SZ': 1148133.0, 'GT': 17581476.0, 'KZ': 18551428.0, 'MR': 4525698.0, nan: 2494524.0, 'RW': 12626938.0, 'LC': 182795.0, 'SC': 97741.0, 'SR': 581363.0, 'UY': 3461731.0, 'VE': 28515829.0, 'BS': 389486.0, 'CF': 4745179.0, 'CG': 5380504.0, 'UZ': 32981715.0, 'BJ': 11801151.0, 'LR': 4937374.0, 'MM': 54045422.0, 'SO': 15442906.0, 'TZ': 58005461.0, 'BB': 287021.0, 'GM': 2347696.0, 'ME': 622182.0, 'DJ': 973557.0, 'SV': 6453550.0, 'PF': 279285.0, 'GU': 167295.0, 'KG': 6415851.0, 'NI': 6545503.0, 'ZM': 17861034.0, 'BM': 62508.0, 'KY': 64948.0, 'TD': 15946882.0, 'FJ': 889955.0, 'GI': 33706.0, 'GL': 56660.0, 'GG': 64468.0, 'HT': 11263079.0, 'JE': 107796.0, 'MU': 1269670.0, 'CV': 549936.0, 'IM': 84589.0, 'MG': 26969306.0, 'MS': 4991.0, 'NC': 282757.0, 'NE': 23310719.0, 'PG': 8776119.0, 'ZW': 14645473.0, 'AO': 31825299.0, 'ER': 3497117.0, 'TL': 1293120.0, 'UG': 44269587.0, 'DM': 71808.0, 'GD': 112002.0, 'MZ': 30366043.0, 'SY': 17070132.0, 'BZ': 390351.0, 'VI': 104579.0, 'LA': 7169456.0, 'LY': 6777453.0, 'TC': 38194.0, 'ML': 19658023.0, 'KN': 52834.0, 'AI': 14872.0, 'VG': 30033.0, 'GW': 1920917.0, 'PR': 2933404.0, 'MP': 57213.0, 'BW': 2303703.0, 'BI': 11530577.0, 'SL': 7813207.0, 'BQ': 25983.0, 'MW': 18628749.0, 'FK': 3372.0, 'SS': 11062114.0, 'ST': 215048.0, 'YE': 29161922.0, 'EH': 582458.0, 'TJ': 9321023.0, 'KM': 850891.0, 'LS': 2125267.0}
